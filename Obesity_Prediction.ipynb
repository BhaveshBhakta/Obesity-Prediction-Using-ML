# %% [markdown]
# # Obesity Prediction

# %% [markdown]
# ## Data Loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/Obesity prediction.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.size
# Out:
# 35887

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          2111 non-null   object
#  1   Age             2111 non-null   float64
#  2   Height          2111 non-null   float64
#  3   Weight          2111 non-null   float64
#  4   family_history  2111 non-null   object
#  5   FAVC            2111 non-null   object
#  6   FCVC            2111 non-null   float64
#  7   NCP             2111 non-null   float64
#  8   CAEC            2111 non-null   object
#  9   SMOKE           2111 non-null   object
#  10  CH2O            2111 non-null   float64
#  11  SCC             2111 non-null   object
#  12  FAF             2111 non-null   float64
#  13  TUE             2111 non-null   float64
#  14  CALC            2111 non-null   object
#  15  MTRANS          2111 non-null   object
#  16  Obesity         2111 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
df.isnull().sum()
# Out:
# Gender            0
# Age               0
# Height            0
# Weight            0
# family_history    0
# FAVC              0
# FCVC              0
# NCP               0
# CAEC              0
# SMOKE             0
# CH2O              0
# SCC               0
# FAF               0
# TUE               0
# CALC              0
# MTRANS            0
# Obesity           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 24

# %% [markdown]
# ## Data Visualization

# %%
# Gender Distribution

plt.figure(figsize=(8, 4))
sns.countplot(data=df, x='Gender', palette='pastel')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Age Distribution

plt.figure(figsize=(8, 4))
sns.histplot(df['Age'], kde=True, color='blue', bins=20)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Obesity Levels by Gender

plt.figure(figsize=(15, 4))
sns.countplot(data=df, x='Obesity', hue='Gender', palette='cool')
plt.title('Obesity Levels by Gender')
plt.xlabel('Obesity Level')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Family History of Obesity

plt.figure(figsize=(8, 4))
sns.countplot(data=df, x='family_history', palette='viridis')
plt.title('Family History of Obesity')
plt.xlabel('Family History (Yes/No)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#  Eating High-Calorie Foods (FAVC)

plt.figure(figsize=(8, 4))
sns.countplot(data=df, x='FAVC', palette='rocket')
plt.title('Preference for High-Calorie Food (FAVC)')
plt.xlabel('FAVC (Yes/No)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Correlation Heatmap (Numerical Variables)

plt.figure(figsize=(10, 8))
correlation_matrix = df[['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='Purples', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap for Numerical Features')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap for Numerical Features')

# %%
# Obesity Level vs Physical Activity (FAF)

plt.figure(figsize=(15, 6))
sns.boxplot(data=df, x='Obesity', y='FAF', palette='muted')
plt.title('Physical Activity (FAF) vs Obesity Level')
plt.xlabel('Obesity Level')
plt.ylabel('FAF (Frequency of Physical Activity)')
# Out:
# Text(0, 0.5, 'FAF (Frequency of Physical Activity)')

# %%
# Transportation Mode (MTRANS) Distribution

plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='MTRANS', order=df['MTRANS'].value_counts().index, palette='crest')
plt.title('Mode of Transportation (MTRANS)')
plt.xlabel('Transportation Mode')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Water Consumption (CH2O) vs Obesity Level

plt.figure(figsize=(15, 6))
sns.boxplot(data=df, x='Obesity', y='CH2O', palette='plasma')
plt.title('Water Consumption (CH2O) vs Obesity Level')
plt.xlabel('Obesity Level')
plt.ylabel('CH2O (Liters per Day)')
# Out:
# Text(0, 0.5, 'CH2O (Liters per Day)')

# %%
# Alcohol Consumption (CALC) vs Obesity Level

plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='CALC', hue='Obesity', palette='viridis')
plt.title('Alcohol Consumption (CALC) vs Obesity Level')
plt.xlabel('Alcohol Consumption Frequency')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Smoking Habit (SMOKE) Distribution

plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='SMOKE', palette='coolwarm')
plt.title('Smoking Habit Distribution')
plt.xlabel('Smoking Habit (Yes/No)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Weight vs Height Scatter Plot by Obesity Level

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Height', y='Weight', hue='Obesity', palette='viridis', alpha=0.8)
plt.title('Height vs Weight by Obesity Level')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
# Out:
# Text(0, 0.5, 'Weight (kg)')

# %%
# Transportation Mode (MTRANS) vs Physical Activity (FAF)

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='MTRANS', y='FAF', palette='Set2')
plt.title('Transportation Mode vs Physical Activity')
plt.xlabel('Transportation Mode')
plt.ylabel('Frequency of Physical Activity (FAF)')
# Out:
# Text(0, 0.5, 'Frequency of Physical Activity (FAF)')

# %% [markdown]
# ## Data Cleaning and Preprocessing

# %%
# Dropping duplicated row

df = df.drop_duplicates()

# %%
# Creating BMI Feature

df["BMI"] = df["Weight"] / (df["Height"] ** 2)

df = df.drop(["Weight", "Height"], axis=1)

# %%
# Ordinal Encoding

from sklearn.preprocessing import OrdinalEncoder

category_column = ["Gender","family_history","FAVC","CAEC","SMOKE","SCC","CALC"]

oe = OrdinalEncoder()

df[category_column] = oe.fit_transform(df[category_column])

# %%
# One Hot Encoding

df = pd.get_dummies(columns=["MTRANS"],data=df,drop_first=True)

# %%
# Label Encoding

from sklearn.preprocessing import LabelEncoder

boolean_cols_auto = df.select_dtypes(include=['bool']).columns
df[boolean_cols_auto] = df[boolean_cols_auto].astype(int)

le = LabelEncoder()
df["Obesity"] = le.fit_transform(df["Obesity"])

# %%
## Train Test And Split

from sklearn.model_selection import train_test_split

x = df.drop(['Obesity'], axis = 1)
y = df['Obesity']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42,stratify=y)

# %%
# Standard Scaler

from sklearn.preprocessing import StandardScaler

ss = StandardScaler()

x_train_scaled = ss.fit_transform(x_train)
x_test_scaled = ss.transform(x_test)

# %%
train_accuracy_scores = []
train_precision_scores = []
train_recall_scores = []
train_f1_scores = []

test_accuracy_scores = []
test_precision_scores = []
test_recall_scores = []
test_f1_scores = []

# %%
def evaluate_classification_performance(model, x_train, y_train, x_test, y_test, score_append=False):

    # Fit the model
    model.fit(x_train, y_train)

    # Predict on train and test datasets
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)

    # Calculate metrics for the training set
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_precision = precision_score(y_train, y_train_pred, average='weighted')
    train_recall = recall_score(y_train, y_train_pred, average='weighted')
    train_f1 = f1_score(y_train, y_train_pred, average='weighted')

    # Calculate metrics for the test set
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_precision = precision_score(y_test, y_test_pred, average='weighted')
    test_recall = recall_score(y_test, y_test_pred, average='weighted')
    test_f1 = f1_score(y_test, y_test_pred, average='weighted')

    # Optionally append scores to global lists
    if score_append:
        train_accuracy_scores.append(train_accuracy)
        train_precision_scores.append(train_precision)
        train_recall_scores.append(train_recall)
        train_f1_scores.append(train_f1)

        test_accuracy_scores.append(test_accuracy)
        test_precision_scores.append(test_precision)
        test_recall_scores.append(test_recall)
        test_f1_scores.append(test_f1)

    # Generate confusion matrices
    train_cm = confusion_matrix(y_train, y_train_pred)
    test_cm = confusion_matrix(y_test, y_test_pred)

    # Plot confusion matrices
    def plot_confusion_matrix(cm, title, labels):
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
        plt.title(title)
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.show()

    print(f"{model.__class__.__name__} Performance Metrics:")
    print(f"Training Data: Accuracy = {train_accuracy:.2f}, Precision = {train_precision:.2f}, Recall = {train_recall:.2f}, F1-score = {train_f1:.2f}")
    print(f"Testing Data : Accuracy = {test_accuracy:.2f}, Precision = {test_precision:.2f}, Recall = {test_recall:.2f}, F1-score = {test_f1:.2f}\n")
    class_labels = sorted(set(y_train))

    print("Training Confusion Matrix:")
    plot_confusion_matrix(train_cm, "Training Confusion Matrix", class_labels)

    print("Testing Confusion Matrix:")
    plot_confusion_matrix(test_cm, "Testing Confusion Matrix", class_labels)

# %% [markdown]
# ## Model Building and Prediction

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
from sklearn.ensemble import GradientBoostingClassifier

evaluate_classification_performance(
    model=GradientBoostingClassifier(),
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test,
    score_append = True
)
# Out:
# GradientBoostingClassifier Performance Metrics:
# Training Data: Accuracy = 1.00, Precision = 1.00, Recall = 1.00, F1-score = 1.00
# Testing Data : Accuracy = 0.97, Precision = 0.97, Recall = 0.97, F1-score = 0.97
#
# Training Confusion Matrix:
# Testing Confusion Matrix:
